# %% [markdown]
# 1.  Jelaskan makna dataset. Jelaskan pula makna data training dan data testing!
#
# A. Dataset
#
# Dataset adalah kumpulan data yang terurut. Saat mengolah data, dataset dapat berupa sekumpulan tabel, skema, dan objek lainnya. Dataset pada dasarnya diatur untuk model terteyang membantu untuk memproses informasi yang dibutuhkan. Dataset juga merupakan kumpulan informasi yang disimpan secara permanen yang biasanya berisi data tingkat kasus, data ydikumpulkan, atau data tingkat panduan statistik.
# Dataset menggambarkan nilai untuk setiap variabel untuk jumlah yang tidak diketahui seperti tinggi, berat, suhu, volume, dll. dari suatu objek atau nilai angka acak. Nilai-nidalam himpunan ini dikenal sebagai datum. Dataset terdiri dari data dari satu atau lebih elemen yang sesuai dengan setiap baris.
#
# B. Data Training
#
# Jenis data ini membangun algoritma machine learning. Ilmuwan data/data scientist memasukkan algoritma input data, yang sesuai dengan keluaran yang diharapkan. Model mengevaluasi data berulang kali untuk mempelajari lebih lanjut tentang perilaku data dan kemudian menyesuaikan untuk memenuhi tujuan yang dimaksudkan.
#
# C. Data Testing
#
# Setelah model dibangun, data testing akan sekali lagi memvalidasi bahwa model tersebut dapat membuat prediksi yang akurat. Jika data training dan validasi menyertakan label untuk memantau metrik kinerja model, data testing sebaiknya tidak diberi label. Data testing memberikan pemeriksaan akhir real-world dari kumpulan data yang tidak terlihat untuk mengonfirmasi bahwa algoritma ML telah dilatih secara efektif.

# %% [markdown]
# 2. Jelaskan proses penyusunan dataset
#
# a. menentukan sebuah atribut dari suatu data
#
# b. memberikan value/element data dari atribut yang tadi telah ditentukan
#
# c. menentukan pola apa saja dari sebuah atribut data
#
# d. menentukan sebuah kelas yang dihasilkan berdasarkan value atribut

# %% [markdown]
# 3. makna atribut dataset iris dan kelas dataset iris
#
# dataset bunga Iris adalah dataset multivariat yang diperkenalkan oleh ahli statistik Inggris dan
# ahli biologi Ronald Fisher dalam makalahnya tahun 1936 tentang penggunaan beberapa pengukuran dalam masalah taksonomi. Kadang-kadang disebut dataset Iris Anderson karena Edgar Anderson mengumpulkan
# data untuk mengukur variasi morfologi bunga Iris dari tiga spesies terkait. dataset
# terdiri dari 50 sampel dari masing-masing tiga spesies Iris (Iris Setosa, Iris virginica, dan Iris
# versikolor). Empat fitur diukur dari setiap sampel: panjang dan lebar
# sepal dan petal, dalam sentimeter. Dataset ini menjadi kasus uji khas untuk banyak statistik
# teknik klasifikasi dalam pembelajaran mesin seperti support vector machine. dataset
# berisi satu set 150 catatan di bawah 5 atribut - Panjang Petal, Lebar Petal, Panjang Sepal, Sepal
# lebar dan Kelas (Spesies).

# %% [markdown]
# 4. Masukkan dataset iris sebagai array 2D di numpy. Pisahkan setiap kelas di array yang berbeda : setosa, versicolor, virginica, dan unknown

# %%
import numpy as np
import matplotlib.pyplot as plt

setosa = np.array([
[0.2,	1.4,	3.5,	5.1],
[0.2,	1.4,	3,	4.9],
[0.2,	1.3,	3.2,	4.7],
[0.2,	1.5,	3.1,	4.6],
[0.2,	1.4,	3.6,	5],
[0.4,	1.7,	3.9,	5.4],
[0.3,	1.4,	3.4,	4.6],
[0.2,	1.5,	3.4,	5],
[0.2,	1.4,	2.9,	4.4],
[0.1,	1.5,	3.1,	4.9],
[0.2,	1.5,	3.7,	5.4],
[0.2,	1.6,	3.4,	4.8],
[0.1,	1.4,	3,	4.8],
[0.1,	1.1,	3,	4.3],
[0.2,	1.2,	4,	5.8],
[0.4,	1.5,	4.4,	5.7],
[0.4,	1.3,	3.9,	5.4],
[0.3,	1.4,	3.5,	5.1],
[0.3,	1.7,	3.8,	5.7],
[0.3,	1.5,	3.8,	5.1],
[0.2,	1.7,	3.4,	5.4],
[0.4,	1.5,	3.7,	5.1],
[0.2,	1,	3.6,	4.6],
[0.5,	1.7,	3.3,	5.1],
[0.2,	1.9,	3.4,	4.8],
[0.2,	1.6,	3,	5],
[0.4,	1.6,	3.4,	5],
[0.2,	1.5,	3.5,	5.2],
[0.2,	1.4,	3.4,	5.2],
[0.2,	1.6,	3.2,	4.7],
[0.2,	1.6,	3.1,	4.8],
[0.4,	1.5,	3.4,	5.4],
[0.1,	1.5,	4.1,	5.2],
[0.2,	1.4,	4.2,	5.5],
[0.2,	1.5,	3.1,	4.9],
[0.2,	1.2,	3.2,	5],
[0.2,	1.3,	3.5,	5.5],
[0.1,	1.4,	3.6,	4.9],
[0.2,	1.3,	3,	4.4],
[0.2,	1.5,	3.4,	5.1],
[0.3,	1.3,	3.5,	5],
[0.3,	1.3,	2.3,	4.5],
[0.2,	1.3,	3.2,	4.4],
[0.6,	1.6,	3.5,	5],
[0.4,	1.9,	3.8,	5.1]
])

verginica = np.array([
[2.5,	6,	3.3,	6.3],
[1.9,	5.1,	2.7,	5.8],
[2.1,	5.9,	3,	7.1],
[1.8,	5.6,	2.9,	6.3],
[2.2,	5.8,	3,	6.5],
[2.1,	6.6,	3,	7.6],
[1.7,	4.5,	2.5,	4.9],
[1.8,	6.3,	2.9,	7.3],
[1.8,	5.8,	2.5,	6.7],
[2.5,	6.1,	3.6,	7.2],
[2,	5.1,	3.2,	6.5],
[1.9,	5.3,	2.7,	6.4],
[2.1,	5.5,	3,	6.8],
[2,	5,	2.5,	5.7],
[2.4,	5.1,	2.8,	5.8],
[2.3,	5.3,	3.2,	6.4],
[1.8,	5.5,	3, 6.5],
[2.2,	6.7,	3.8,	7.7],
[2.3,	6.9,	2.6,	7.7],
[1.5,	5,	2.2,	6],
[2.3,	5.7,	3.2,	6.9],
[2,	4.9,	2.8,	5.6],
[2,	6.7,	2.8,	7.7],
[1.8,	4.9,	2.7,	6.3],
[2.1,	5.7,	3.3,	6.7],
[1.8,	6,	3.2,	7.2],
[1.8,	4.8,	2.8,	6.2],
[1.8,	4.9,	3,	6.1],
[2.1,	5.6,	2.8,	6.4],
[1.6,	5.8,	3,	7.2],
[1.9,	6.1,	2.8,	7.4],
[2,	6.4,	3.8,	7.9],
[2.2,	5.6,	2.8,	6.4],
[1.5,	5.1,	2.8,	6.3],
[1.4,	5.6,	2.6,	6.1],
[2.3,	6.1,	3,	7.7],
[2.4,	5.6,	3.4,	6.3],
[1.8,	5.5,	3.1,	6.4],
[1.8,	4.8,	3,	6],
[2.1,	5.4,	3.1,	6.9],
[2.4,	5.6,	3.1,	6.7],
[2.3,	5.1,	3.1,	6.9],
[1.9,	5.1,	2.7,	5.8],
[2.3,	5.9,	3.2,	6.8],
[2.5,	5.7,	3.3,	6.7]
])

versicolor = np.array([
[1.4,	4.7,	3.2,	7],
[1.5,	4.5,	3.2,	6.4],
[1.5,	4.9,	3.1,	6.9],
[1.3,	4,	2.3,	5.5],
[1.5,	4.6,	2.8,	6.5],
[1.3,	4.5,	2.8,	5.7],
[1.6,	4.7,	3.3,	6.3],
[1,	3.3,	2.4,	4.9],
[1.3,	4.6,	2.9,	6.6],
[1.4,	3.9,	2.7,	5.2],
[1,	3.5,	2,	5],
[1.5,	4.2,	3,	5.9],
[1,	4,	2.2,	6],
[1.4,	4.7,	2.9,	6.1],
[1.3,	3.6,	2.9,	5.6],
[1.4,	4.4,	3.1,	6.7],
[1.5,	4.5,	3,	5.6],
[1,	4.1,	2.7,	5.8],
[1.5,	4.5,	2.2,	6.2],
[1.1,	3.9,	2.5,	5.6],
[1.8,	4.8,	3.2,	5.9],
[1.3,	4,	2.8,	6.1],
[1.5,	4.9,	2.5,	6.3],
[1.2,	4.7,	2.8,	6.1],
[1.3,	4.3,	2.9,	6.4],
[1.4,	4.4,	3,	6.6],
[1.4,	4.8,	2.8,	6.8],
[1.7,	5,	3,	6.7],
[1.5,	4.5,	2.9,	6],
[1,	3.5,	2.6,	5.7],
[1.1,	3.8,	2.4,	5.5],
[1,	3.7,	2.4,	5.5],
[1.2,	3.9,	2.7,	5.8],
[1.6,	5.1,	2.7,	6],
[1.5,	4.5,	3,	5.4],
[1.6,	4.5,	3.4,	6],
[1.5,	4.7,	3.1,	6.7],
[1.3,	4.4,	2.3,	6.3],
[1.3,	4.1,	3,	5.6],
[1.3,	4,	2.5,	5.5],
[1.2,	4.4,	2.6,	5.5],
[1.4,	4.6,	3,	6.1],
[1.2,	4,	2.6,	5.8],
[1,	3.3,	2.3,	5],
[1.3,	4.2,	2.7,	5.6]                       
])

unknown = np.array([
[0.3,	1.4,	3,	4.8],
[0.2,	1.6,	3.8,	5.1],
[0.2,	1.4,	3.2,	4.6],
[0.2,	1.5,	3.7,	5.3],
[0.2,	1.4,	3.3,	5],
[1.2,	4.2,	3,	5.7],
[1.3,	4.2,	2.9,	5.7],
[1.3,	4.3,	2.9,	6.2],
[1.1,	3,	2.5,	5.1],
[1.3,	4.1,	2.8,	5.7],
[2.3,	5.2,	3,	6.7],
[1.9,	5,	2.5,	6.3],
[2,	5.2,	3,	6.5],
[2.3,	5.4,	3.4,	6.2],
[1.8,	5.1,	3,	5.9]                    
])

print("setosa \n", setosa, "\n")
print("verginica \n", verginica, "\n")
print("versicolor \n", versicolor, "\n")
print("unknown \n", unknown, "\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# g:\.shortcut-targets-by-id\1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN\SIBEUX\KULIAH\00 - UNEJ\Algorithm Programming\PEMROGRAMAN\Main Program\Python\Data Science\.collage\data-mining\.praktikum\module-2.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=3'>4</a> setosa = np.array([
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=4'>5</a> [0.2,	1.4,	3.5,	5.1],
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=5'>6</a> [0.2,	1.4,	3,	4.9],
#    (...)
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=48'>49</a> [0.4,	1.9,	3.8,	5.1]
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=49'>50</a> ])
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=51'>52</a> verginica = np.array([
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=52'>53</a> [2.5,	6,	3.3,	6.3],
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=53'>54</a> [1.9,	5.1,	2.7,	5.8],
#    (...)
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=96'>97</a> [2.5,	5.7,	3.3,	6.7]
#      <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.praktikum/module-2.ipynb#ch0000004?line=97'>98</a> ])
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# 5.	Buatlah scatter plot yang menggunakan pasangan attribut berikut pada setiap kelas (termasuk unknown). Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica, dan kuning untuk unknown
#
# A.	Sepal length [3] dan petal width [0]
#
# B.	Sepal width [2] petal length [1]
#
# C.	Sepal width [2] dan petal width [0]
#
# D.	Sepal length [3] dan petal length [1]

# %%
# 

a1 = setosa[:,3]
a2 = setosa[:,1]
b1 = verginica[:,3]
b2 = verginica[:,1]
c1 = versicolor[:,3]
c2 = versicolor[:,1]
d1 = unknown[:,3]
d2 = unknown[:,1]

plt.scatter(a1, a2, color='red')
plt.scatter(b1, b2, color='blue')
plt.scatter(c1, c2, color='green')
plt.scatter(d1, d2, color='yellow')

# %% [markdown]
# 6.	Jelaskan bagaimana karakter pengelompokan setiap kelas pada scatterplot

# %%
pw = verginica[:,0]
pl = verginica[:,1]
sw = verginica[:,2]
sl = verginica[:,3]

plt.scatter(sl, pw, color='blue')
plt.scatter(sw, pl, color='blue')
plt.scatter(sw, pw, color='blue')
plt.scatter(sl, pl, color='blue')

# %% [markdown]
# 7.	Perhatikan data yang berjenis unknown. Jelaskan bagaimana cara meramal jenis data unknown

# %%
a1 = setosa[:,3]
a2 = setosa[:,0]
b1 = verginica[:,3]
b2 = verginica[:,0]
c1 = versicolor[:,3]
c2 = versicolor[:,0]
d1 = unknown[:,3]
d2 = unknown[:,0]

plt.scatter(a1, a2, color='red')
plt.scatter(b1, b2, color='blue')
plt.scatter(c1, c2, color='green')
plt.scatter(d1, d2, color='yellow')

# %% [markdown]
# 8.	Buatlah pararrel coordinat plot dari data yang berkelas setosa, versicolor, dan virginica. Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica. Hint gunakan perintah plot dan operasi slicing pada numpy untuk mempermudah tugas anda

# %%
name = ["petal width", "petal length", "sepal width", "sepal length"]

for x in range(len(setosa)):
    plt.plot(name, setosa[x,:], color='red')
for x in range(len(verginica)):
    plt.plot(name, verginica[x,:], color='blue')
for x in range(len(versicolor)):
    plt.plot(name, versicolor[x,:], color='green')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\.shortcut-targets-by-id\1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN\SIBEUX\KULIAH\00 - UNEJ\Algorithm Programming\PEMROGRAMAN\Main Program\Python\Data Science\.collage\data-mining\.PRAK\module-2.ipynb Cell 13' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.PRAK/module-2.ipynb#ch0000012?line=0'>1</a> name = ["petal width", "petal length", "sepal width", "sepal length"]
# ----> <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.PRAK/module-2.ipynb#ch0000012?line=2'>3</a> for x in range(len(setosa)):
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.PRAK/module-2.ipynb#ch0000012?line=3'>4</a>     plt.plot(name, setosa[x,:], color='red')
#       <a href='vscode-notebook-cell:/g%3A/.shortcut-targets-by-id/1GLhesaekxPRKr-lkNYX-mtfouqJhqhXN/SIBEUX/KULIAH/00%20-%20UNEJ/Algorithm%20Programming/PEMROGRAMAN/Main%20Program/Python/Data%20Science/.collage/data-mining/.PRAK/module-2.ipynb#ch0000012?line=4'>5</a> for x in range(len(verginica)):
#
# NameError: name 'setosa' is not defined

# %% [markdown]
# 9.	Jelaskan bagaimana karakter pengelompokan setiap kelas pada scatterplot (parallel coordinat?)
